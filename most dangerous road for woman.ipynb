# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings #library to stop showing warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("most-dangerous-countries-for-women-2024.csv")
df.head(10)
# Out:
#          country  \
# 0          India
# 1          China
# 2  United States
# 3      Indonesia
# 4       Pakistan
# 5        Nigeria
# 6         Brazil
# 7     Bangladesh
# 8         Russia
# 9       Ethiopia
#
#    MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  \
# 0                                              0.595
# 1                                              0.700
# 2                                              0.823
# 3                                              0.700
# 4                                              0.481
# 5                                              0.465
# 6                                              0.630
# 7                                              0.593
# 8                                              0.752
# 9                                              0.521
#
#    MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019  \
# 0                                             541.25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   country                                                               176 non-null    object
#  1   MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  176 non-null    float64
#  2   MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019   50 non-null     float64
#  3   MostDangerousCountriesForWomen_WDIStreetSafety_2019                   50 non-null     float64
#  4   MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019            50 non-null     float64
#  5   MostDangerousCountriesForWomen_WDINonPartnerViolence_2019             50 non-null     float64
# ...

# %%
df.columns
# Out:
# Index(['country',
#        'MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023',
#        'MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019',
#        'MostDangerousCountriesForWomen_WDIStreetSafety_2019',
#        'MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019',
#        'MostDangerousCountriesForWomen_WDINonPartnerViolence_2019',
#        'MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019',
#        'MostDangerousCountriesForWomen_WDILegalDiscrimination_2019',
#        'MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019',
#        'MostDangerousCountriesForWomen_WDIGenderInequality_2019',
#        'MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019'],
#       dtype='object')

# %%
df.tail()
# Out:
#                    country  \
# 171               Barbados
# 172  Sao Tome and Principe
# 173                  Samoa
# 174             Seychelles
# 175                  Tonga
#
#      MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  \
# 171                                              0.779
# 172                                              0.648
# 173                                              0.711
# 174                                              0.799
# 175                                              0.697
#
#      MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019  \
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
#
#      MostDangerousCountriesForWomen_WDIStreetSafety_2019  \
# ...

# %%
df.describe()
# Out:
#        MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  \
# count                                         176.000000
# mean                                            0.680330
# std                                             0.148371
# min                                             0.286000
# 25%                                             0.581500
# 50%                                             0.691500
# 75%                                             0.796500
# max                                             0.932000
#
#        MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019  \
# count                                          50.000000
# mean                                          413.011600
# std                                           122.215655
# min                                           212.040000
# 25%                                           312.602500
# 50%                                           394.535000
# ...

# %%
df.shape
# Out:
# (176, 11)

# %%
df.isnull().sum()
# Out:
# country                                                                   0
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023      0
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019     126
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                     126
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019              126
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019               126
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019          126
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019              126
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                  126
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                 126
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019          126
# dtype: int64

# %%
df.dtypes
# Out:
# country                                                                  object
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023    float64
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019     float64
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                     float64
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019              float64
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019               float64
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019          float64
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019              float64
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                  float64
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                 float64
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019          float64
# dtype: object

# %%
df.nunique()
# Out:
# country                                                                 176
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023    147
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019      50
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                      35
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019               22
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019                22
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019           33
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019               24
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                   30
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                  40
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019           28
# dtype: int64

# %%
correlation = df.corr()
df.corr()
# Out:
#                                                     MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  \
# MostDangerousCountriesForWomen_WomenPeaceAndSec...                                           1.000000
# MostDangerousCountriesForWomen_WomensDangerInde...                                          -0.792908
# MostDangerousCountriesForWomen_WDIStreetSafety_...                                          -0.635463
# MostDangerousCountriesForWomen_WDIIntentionalHo...                                          -0.399900
# MostDangerousCountriesForWomen_WDINonPartnerVio...                                           0.179195
# MostDangerousCountriesForWomen_WDIIntimatePartn...                                          -0.352155
# MostDangerousCountriesForWomen_WDILegalDiscrimi...                                          -0.379034
# MostDangerousCountriesForWomen_WDIGlobalGenderG...                                          -0.553413
# ...

# %%
sns.heatmap(correlation, annot=True)
# Out:
# <AxesSubplot:>

# %%
from random import sample
df = sample(range(1, 1000), 100)
plt.hist(df)
# Out:
# (array([ 9., 12.,  7.,  9.,  8.,  8., 10., 11., 11., 15.]),
#  array([  5. , 103.3, 201.6, 299.9, 398.2, 496.5, 594.8, 693.1, 791.4,
#         889.7, 988. ]),
#  <BarContainer object of 10 artists>)

# %%
df=pd.read_csv("most-dangerous-countries-for-women-2024.csv")

# %%
df["MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019"].fillna(df["MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019"].median(), inplace=True)
df["MostDangerousCountriesForWomen_WDILegalDiscrimination_2019"].fillna(df["MostDangerousCountriesForWomen_WDILegalDiscrimination_2019"].mode()[0], inplace= True)
#df["MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019"].fillna(df["MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019"].median()[0], inplace= true)
#df.drop(columns=["Cabin"], inplace= True)

# %%
#df.drop(columns=["MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019"], inplace= True)
#df.drop(columns=["MostDangerousCountriesForWomen_WDIGenderInequality_2019"], inplace= True)
#df.drop(columns=["MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019"], inplace= True)
#df.drop(columns=["MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019"], inplace= True)
#df.drop(columns=["MostDangerousCountriesForWomen_WDIStreetSafety_2019"], inplace= True)

# %%
df.isnull().sum()
# Out:
# country                                                                   0
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023      0
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019     126
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                     126
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019              126
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019               126
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019            0
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019                0
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                  126
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                 126
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019          126
# dtype: int64

# %%
#to drop all missing data
#df = df.dropna(how = 'all')
df
# Out:
#                    country  \
# 0                    India
# 1                    China
# 2            United States
# 3                Indonesia
# 4                 Pakistan
# ..                     ...
# 171               Barbados
# 172  Sao Tome and Principe
# 173                  Samoa
# 174             Seychelles
# 175                  Tonga
#
#      MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  \
# 0                                                0.595
# 1                                                0.700
# 2                                                0.823
# 3                                                0.700
# 4                                                0.481
# ..                                                 ...
# 171                                              0.779
# 172                                              0.648
# 173                                              0.711
# ...

# %%
df.isnull().sum()
# Out:
# country                                                                   0
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023      0
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019     126
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                     126
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019              126
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019               126
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019            0
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019                0
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                  126
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                 126
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019          126
# dtype: int64

# %%
#filling missing values with the previous known value(ffill)
#also fill missing value with the next known value(bfill)

df['MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019'].fillna(method = 'ffill', inplace = True)
df['MostDangerousCountriesForWomen_WDIStreetSafety_2019'].fillna(method = 'ffill', inplace = True)
df['MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019'].fillna(method = 'ffill', inplace = True)
df['MostDangerousCountriesForWomen_WDINonPartnerViolence_2019'].fillna(method = 'ffill', inplace = True)
df['MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019'].fillna(method = 'ffill', inplace = True)
df['MostDangerousCountriesForWomen_WDIGenderInequality_2019'].fillna(method = 'ffill', inplace = True)
df['MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019'].fillna(method = 'ffill', inplace = True)

# %%
df.isnull().sum()
# Out:
# country                                                                 0
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023    0
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019     0
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                     0
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019              0
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019               0
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019          0
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019              0
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                  0
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                 0
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019          0
# dtype: int64

# %%
df.groupby(['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023'])['MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019'].max()
# Out:
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023
# 0.286    494.11
# 0.287    494.11
# 0.378    259.92
# 0.384    408.23
# 0.388    468.26
#           ...
# 0.920    259.92
# 0.924    476.09
# 0.926    326.42
# 0.928    252.78
# 0.932    320.65
# Name: MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019, Length: 147, dtype: float64

# %%
df.groupby(['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023'])['MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019'].sum()
# Out:
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023
# 0.286     494.11
# 0.287     494.11
# 0.378     259.92
# 0.384     408.23
# 0.388     468.26
#           ...
# 0.920     259.92
# 0.924    1197.44
# 0.926     326.42
# 0.928     252.78
# 0.932     320.65
# Name: MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019, Length: 147, dtype: float64

# %%
#f.groupby(['Product'])['Quantity Ordered','Price Each'].sum()

# %%
df.groupby(['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023'])['MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019',"MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019"].sum()
# Out:
#                                                     MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019  \
# MostDangerousCountriesForWomen_WomenPeaceAndSec...
# 0.286                                                                                          494.11
# 0.287                                                                                          494.11
# 0.378                                                                                          259.92
# 0.384                                                                                          408.23
# 0.388                                                                                          468.26
# ...                                                                                               ...
# 0.920                                                                                          259.92
# ...

# %% [markdown]
# # visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt


#print("survive rate by gender")

# %%
plt.figure(figsize=(6,5))
sns.countplot(x="MostDangerousCountriesForWomen_WDINonPartnerViolence_2019", hue="country", data=df, palette="coolwarm")
plt.title("intimate partner violence")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["country"],  bins=30, kde=True, color="green")
plt.title("legal descrimination")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["MostDangerousCountriesForWomen_WDILegalDiscrimination_2019"], bins=30, kde=True, color="red")
plt.title("legal descrimination")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023"],  bins=30, kde=True, color="blue")
plt.title("legal descrimination")
plt.show()

# %%
plt.figure(figsize=(8,6))


top_10_product = df.sort_values(by = "MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019", ascending = False).head(100)
plt.bar(top_10_product["MostDangerousCountriesForWomen_WDINonPartnerViolence_2019"],top_10_product["country"],color= "blue")
#plt.xticks(rotation =- 45)
plt.ylabel("country")
plt.xlabel("security")
plt.xticks(rotation = "vertical")
plt.show()

# %%
df.isnull().sum()
# Out:
# country                                                                 0
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023    0
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019     0
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                     0
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019              0
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019               0
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019          0
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019              0
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                  0
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                 0
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019          0
# dtype: int64

# %%
y = df['MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019']
x = df['country']
plt.ylabel('violence partner')
plt.xlabel('country')
plt.title('violence against country')
plt.scatter(x,y)
plt.show()

# %%
y = df['MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019']
x = df['country']
plt.ylabel('violence partner')
plt.xlabel('country')
plt.title('violence against country')
plt.bar(x,y)
plt.show()

# %%
y = df['MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019']
x = df['country']
plt.ylabel('homicide')
plt.xlabel('country')
plt.title('homicide against country')
plt.plot(x,y)
plt.show()

# %%
sns.boxplot(y=df["MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019"])
# Out:
# <AxesSubplot:ylabel='MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019'>

# %%
sns.boxplot(y=df["MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019"])
# Out:
# <AxesSubplot:ylabel='MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019'>

# %%
sns.boxplot(x=df["MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019"])
# Out:
# <AxesSubplot:xlabel='MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019'>

# %%
sns.set(style='whitegrid')
sns.boxplot(y=df["MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019"])
sns.boxplot(x=df["MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019"])
#set figure size
figure= plt.subplots(figsize=(10,6))
#create box plot
plot = sns.boxplot(df=df, width=0.8)

#title
plt.title('INSIGHT')

plt.show()

# %%
df.isnull().sum()
# Out:
# country                                                                 0
# MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023    0
# MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019     0
# MostDangerousCountriesForWomen_WDIStreetSafety_2019                     0
# MostDangerousCountriesForWomen_WDIIntentionalHomicide_2019              0
# MostDangerousCountriesForWomen_WDINonPartnerViolence_2019               0
# MostDangerousCountriesForWomen_WDIIntimatePartnerViolence_2019          0
# MostDangerousCountriesForWomen_WDILegalDiscrimination_2019              0
# MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019                  0
# MostDangerousCountriesForWomen_WDIGenderInequality_2019                 0
# MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019          0
# dtype: int64

# %%
df["MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023"].value_counts()
# Out:
# 0.595    3
# 0.481    3
# 0.610    3
# 0.738    3
# 0.924    3
#         ..
# 0.505    1
# 0.737    1
# 0.651    1
# 0.580    1
# 0.697    1
# Name: MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023, Length: 147, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
df["country"]= LabelEncoder().fit_transform(df["country"])
#df["Embarked"]=LabelEncoder().fit_transform(df["Embarked"])
df.head()
# Out:
#    country  \
# 0       67
# 1       31
# 2      167
# 3       68
# 4      115
#
#    MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023  \
# 0                                              0.595
# 1                                              0.700
# 2                                              0.823
# 3                                              0.700
# 4                                              0.481
#
#    MostDangerousCountriesForWomen_WomensDangerIndexWDI_TotalScore_2019  \
# 0                                             541.25
# 1                                             444.55
# 2                                             456.31
# 3                                             442.10
# 4                                             442.10
#
#    MostDangerousCountriesForWomen_WDIStreetSafety_2019  \
# 0                                               41.0
# 1                                               23.0
# ...

# %%
label_counts = df["MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023"].value_counts()
df["MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023"].value_counts()
valid_labels = label_counts[label_counts >1].index
df_filtered = df[df["MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023"].isin(valid_labels)]

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, LabelEncoder
import numpy as np

 
#handle missing values
imputer= SimpleImputer(strategy='mean')
df['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023']= imputer.fit_transform(df[['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023']])
#df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
#df['Fare']= imputer.fit_transform(df[['Fare']])

#Drop the 'cabin' column
df.drop(columns=['MostDangerousCountriesForWomen_WDIGlobalGenderGap_2019',"MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019","MostDangerousCountriesForWomen_WDIStreetSafety_2019"])
#encode categorical variables
#label_encoder= LabelEncoder()
df['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023']= label_encoder.fit_transform(df['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023'])
df['MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019']= label_encoder.fit_transform(df['MostDangerousCountriesForWomen_WDIAttitudesTowardViolence_2019'])

#define features and target variable
x= df_filtered.drop(columns=['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023'])#features
y= df_filtered['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023']#our target

#split the data into training and testing sets
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=23, random_state=42, stratify=y)

#scale the features
scaler= StandardScaler()
x_train= scaler.fit_transform(x_train)
x_test= scaler.transform(x_test)

print('Data Processing Completed')
# Out:
# Data Processing Completed

# %% [markdown]
# random forestclassifier for true or false
# while  random forest regression is for numerical data and numbers

# %%
print(len(x), len(y))
print(x.shape, y.shape)
print(len(x_train), len(y_train))
# Out:
# 52 52
# (52, 10) (52,)
# 29 29

# %%
train , x_test , y_train , y_test =train_test_split(x,y, test_size = 0.8 , random_state = 42)

# %%
#y_pred= rf.predict(x_test)

# %%
x= df_filtered.drop(columns=['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023'])#features
y= df_filtered['MostDangerousCountriesForWomen_WomenPeaceAndSecurityIndex_Score_2023']#our target

#split the data into training and testing sets
x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=23, random_state=42, stratify=y)

# %%
from sklearn.model_selection import train_test_split
#x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2, random_state=42)


print("Training set size:", x_test.shape)
print("Testiimg set size:", x_test.shape)
# Out:
# Training set size: (23, 10)
# Testiimg set size: (23, 10)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
param_dist= {
    "n_estimators": [10,50,100,200,500],
    "max_depth":[None,5,10,15],
    "min_samples_split":[2,5,10],
    "min_samples_leaf":[1,5,10],
    "bootstrap": [True, False] 
}

# %%
rfc = RandomForestClassifier(random_state = 42)
random_search = RandomizedSearchCV(estimator = rfc,param_distributions=param_dist, cv=5,n_iter = 10)

# %%
x_train , x_test , y_train , y_test =train_test_split(x,y, test_size = 0.2 ,random_state = 42)
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
print("predictions:",  y_pred[:10])
print("Actual:", y_test[:10].values)
# Out:
# predictions: [0.63494 0.63006 0.75139 0.74741 0.68046 0.6688  0.54101 0.76638 0.68411
#  0.68061]
# Actual: [0.645 0.619 0.7   0.644 0.664 0.752 0.521 0.924 0.481 0.924]

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:" ,mse)
# Out:
# Mean Squared Error: 0.015167528781818177

# %%
from sklearn.metrics import r2_score
accuracy = r2_score(y_test, y_pred)
print("Accuracy (R2 score):", accuracy)
# Out:
# Accuracy (R2 score): 0.2970745065310716
