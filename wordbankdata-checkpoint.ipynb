# %% [markdown]
# #you must finish it

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import searborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23852\1456705790.py in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import searborn as sns
#
# ModuleNotFoundError: No module named 'searborn'

# %%
df=pd.read_csv("world_bank_dataset.csv")
df.head(25)
# Out:
#            Country  Year     GDP (USD)    Population  Life Expectancy  \
# 0           Brazil  2010  1.493220e+12  8.290200e+08             66.7
# 1            Japan  2011  1.756270e+13  8.970100e+08             61.4
# 2            India  2012  1.642688e+13  6.698500e+08             69.1
# 3           Mexico  2013  1.189001e+13  1.138000e+08             80.1
# 4            India  2014  2.673020e+12  2.971000e+07             62.7
# 5   United Kingdom  2015  1.071180e+13  7.225600e+08             74.6
# 6            China  2016  6.791480e+12  1.492810e+09             84.6
# 7        Indonesia  2017  9.467220e+12  1.182400e+08             80.9
# 8   United Kingdom  2018  1.351403e+13  1.461580e+09             57.0
# 9            India  2019  1.425720e+13  8.020500e+08             59.9
# 10          Canada  2010  1.380270e+13  9.090500e+08             75.4
# 11       Argentina  2011  1.933735e+13  1.084140e+09             55.7
# 12           India  2012  1.049236e+13  8.187800e+08             54.8
# 13         Nigeria  2013  6.052290e+12  4.477000e+08             82.5
# 14           Italy  2014  5.800450e+12  2.387400e+08             63.1
# 15       Indonesia  2015  1.005887e+13  3.489900e+08             62.4
# 16          Turkey  2016  6.110370e+12  2.574800e+08             84.6
# 17    Saudi Arabia  2017  1.503800e+13  1.285920e+09             64.8
# 18         Nigeria  2018  1.171813e+13  1.583100e+08             65.2
# 19    Saudi Arabia  2019  1.298829e+13  7.668800e+08             84.9
# 20    Saudi Arabia  2010  1.164985e+13  1.041990e+09             73.6
# 21          Russia  2011  6.110630e+12  9.324200e+08             71.6
# 22          France  2012  8.354820e+12  2.270200e+08             63.5
# 23           China  2013  1.773535e+13  5.785900e+08             82.6
# 24   United States  2014  1.318373e+13  1.279810e+09             64.8
#
#     Unemployment Rate (%)  CO2 Emissions (metric tons per capita)  \
# 0                    3.81                                   10.79
# 1                   17.98                                   15.67
# 2                   16.02                                    2.08
# 3                    6.26                                   19.13
# 4                    3.10                                   15.66
# 5                   23.24                                    7.55
# 6                   15.59                                   10.18
# 7                   10.91                                    2.87
# 8                    3.29                                    9.29
# 9                   18.61                                   19.10
# 10                  16.03                                    4.95
# 11                  19.14                                   15.86
# 12                   2.83                                   16.49
# 13                   8.56                                   14.32
# 14                   6.24                                   16.54
# 15                   6.82                                    5.43
# 16                   4.08                                    7.08
# 17                   6.12                                   14.07
# 18                  18.78                                   16.61
# 19                  16.91                                    3.41
# 20                   3.20                                    7.29
# 21                   6.56                                    0.81
# 22                   5.37                                   13.85
# 23                  18.97                                   10.62
# 24                  10.97                                    9.72
#
#     Access to Electricity (%)
# 0                       76.76
# 1                       67.86
# 2                       81.08
# 3                       53.46
# 4                       82.17
# 5                       64.48
# 6                       78.46
# 7                       61.41
# 8                       98.05
# 9                       92.80
# 10                      59.87
# 11                      71.43
# 12                      89.31
# 13                      98.22
# 14                      68.43
# 15                      99.76
# 16                      65.68
# 17                      59.02
# 18                      89.47
# 19                      66.31
# 20                      59.27
# 21                      82.59
# 22                      56.94
# 23                      57.82
# 24                      90.13

# %%
df.tail()
# Out:
#             Country  Year     GDP (USD)    Population  Life Expectancy  \
# 195           India  2015  1.110880e+12  6.727800e+08             78.5
# 196       Australia  2016  9.210290e+12  6.896500e+08             64.9
# 197   United States  2017  4.937150e+12  1.234820e+09             61.0
# 198          Canada  2018  1.088696e+13  2.625900e+08             76.5
# 199  United Kingdom  2019  4.525980e+12  5.354700e+08             73.7
#
#      Unemployment Rate (%)  CO2 Emissions (metric tons per capita)  \
# 195                  22.30                                   11.36
# 196                   9.82                                   15.59
# 197                   4.14                                   14.66
# 198                   2.28                                    7.25
# 199                  17.29                                   16.68
#
#      Access to Electricity (%)
# 195                      66.04
# 196                      67.29
# 197                      91.16
# 198                      59.21
# 199                      65.48

# %%
df.isnull()
# Out:
#      Country   Year  GDP (USD)  Population  Life Expectancy  \
# 0      False  False      False       False            False
# 1      False  False      False       False            False
# 2      False  False      False       False            False
# 3      False  False      False       False            False
# 4      False  False      False       False            False
# ..       ...    ...        ...         ...              ...
# 195    False  False      False       False            False
# 196    False  False      False       False            False
# 197    False  False      False       False            False
# 198    False  False      False       False            False
# 199    False  False      False       False            False
#
#      Unemployment Rate (%)  CO2 Emissions (metric tons per capita)  \
# 0                    False                                   False
# 1                    False                                   False
# 2                    False                                   False
# 3                    False                                   False
# 4                    False                                   False
# ..                     ...                                     ...
# 195                  False                                   False
# 196                  False                                   False
# 197                  False                                   False
# 198                  False                                   False
# 199                  False                                   False
#
#      Access to Electricity (%)
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ..                         ...
# 195                      False
# 196                      False
# 197                      False
# 198                      False
# 199                      False
#
# [200 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Country                                   0
# Year                                      0
# GDP (USD)                                 0
# Population                                0
# Life Expectancy                           0
# Unemployment Rate (%)                     0
# CO2 Emissions (metric tons per capita)    0
# Access to Electricity (%)                 0
# dtype: int64

# %%
average_data = df.groupby('Country')[['GDP (USD)', 'Unemployment Rate (%)']].mean().reset_index()

fig = px.scatter(
    average_data,
    x='Unemployment Rate (%)',
    y='GDP (USD)',
    text='Country',
    title='Average GDP vs. Average Unemployment Rate by Country',
    labels={'Unemployment Rate (%)': 'Average Unemployment Rate', 'GDP (USD)': 'Average GDP (USD)'},
    hover_name='Country',
)
fig.show()

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13020\1008660192.py in <module>
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13020\3771845804.py in <module>
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13020\1114064248.py in <module>
# ----> 1 df.column()
#
# NameError: name 'df' is not defined
